# %% [markdown]
# # OpenStreetMap Analysis
#
# Using the OpenStreetMap API and Wiki to document available data for potential involvement with the large geospatial dataset.

# %% [markdown]
# ### Osmnx Demo

# %%
# Library to directly access OSM API and download data
import osmnx as ox

# Download as spatial graph
graph = ox.graph_from_place(place_name)

# Get streets and building instances as GDFs
nodes, edges = ox.graph_to_gdfs(graph)

# Plot Graph
fig, ax = ox.plot_graph(graph)
plt.tight_layout()

# Print as GeoDataFrame
display(edges)

# %% [markdown]
# ### Library Abstraction Demo
#
# Just add easily abstractable tools to the lib folder, in whichever file you prefer. Import by filename.

# %%
from lib.osmtools import osm_to_df

from IPython.display import display

nodes, edges = place_to_gdf(osm_file='./data/osm/map_01.osm')

display(edges)
