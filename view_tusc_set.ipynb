# %% [markdown]
# # View OSM Output for `Tuscaloosa`
#
# Expects a directory with a fully parsed dataset result.

# %%
import os
import lib.misc as m
import lib.geovisual as gv
root = './data/osm-sets'

set_name = 'tuscaloosa_01'
set_folder = os.path.join(root, set_name)

if not os.path.exists(set_folder):
    raise RuntimeError(f"Passed set folder does not exist: '{set_folder}'. Check hyperparameters.")

# %% [markdown]
# ## Inspect Raster Results

# %%
import rasterio as rio
raster_fp = os.path.join(set_folder, set_name + ".tif")

with rio.open(raster_fp) as raster:
    m.print_header("Raster Info")
    print(f"- Width: {raster.width}")
    print(f"- Height: {raster.height}")
    print(f"- Bands: {raster.count}")
    print(f"- Scale: {raster.scales[0]}")
    print(f"- CRS: {raster.crs}")
# Out:
# Raster Info
# -----------
# - Width: 10081
# - Height: 7317
# - Bands: 4
# - Scale: 1.0
# - CRS: EPSG:4326

# %% [markdown]
# ## Building Analysis

# %%
import geopandas as gpd
import shapely.geometry as shp


fp = os.path.join(set_folder, 'buildings.shp')
gdf = gpd.read_file(fp)
gv.gdf_overview(gdf, 'Building GDF')
values = gv.gdf_value_columns(gdf, [k for k in gdf.columns if k not in ['name', 'index', 'geometry']])
# Out:
# Building GDF:
# -------------
# - Rows: 17203
# - Keys: 5
#
# category (4)
#   - 'accountant': 1
#   - 'government': 1
#   - 'multi-storey': 1
#   - 'yes': 1
#
# label (27)
#   - 'house': 11282
#   - 'yes': 4482
#   - 'apartments': 1079
#   - 'static_caravan': 163
#   - 'residential': 34
#   - 'commercial': 25
#   - 'retail': 19
#   - 'roof': 18
#   - 'university': 16
#   - 'greenhouse': 13
#   - 'office': 10
#   - 'school': 10
#   - 'industrial': 10
#   - 'church': 9
#   - 'garage': 6
#   - 'garages': 5
#   - 'service': 5
#   - 'terrace': 5
#   - 'dormitory': 3
#   - 'stadium': 2
#   - 'college': 1
#   - 'construction': 1
#   - 'hotel': 1
#   - 'hospital': 1
#   - 'train_station': 1
#   - 'detached': 1
#   - 'parking': 1
# {'category': category
#  accountant      1
#  government      1
#  multi-storey    1
#  yes             1
#  dtype: int64,
#  'label': label
#  house             11282
#  yes                4482
#  apartments         1079
#  static_caravan      163
#  residential          34
#  commercial           25
#  retail               19
#  roof                 18
#  university           16
#  greenhouse           13
#  office               10
#  school               10
#  industrial           10
#  church                9
#  garage                6
#  garages               5
#  service               5
#  terrace               5
#  dormitory             3
#  stadium               2
#  college               1
#  construction          1
#  hotel                 1
#  hospital              1
#  train_station         1
#  detached              1
#  parking               1
#  dtype: int64}

# %%
import geopandas as gpd
import shapely.geometry as shp


fp = os.path.join(set_folder, 'roads.shp')
gdf = gpd.read_file(fp)
gv.gdf_overview(gdf, "Road GDF")
values = gv.gdf_value_columns(gdf, [k for k in gdf.columns if k not in ['name', 'index', 'geometry']])
# Out:
# Road GDF:
# ---------
# - Rows: 8183
# - Keys: 5
#
# category (10)
#   - 'parking_aisle': 1547
#   - 'sidewalk': 238
#   - 'driveway': 168
#   - 'crossing': 68
#   - 'drive-through': 8
#   - 'motorway_link': 4
#   - 'Busway': 2
#   - 'access_aisle': 2
#   - 'alley': 2
#   - 'emergency_access': 2
#
# label (20)
#   - 'service': 3432
#   - 'footway': 2601
#   - 'residential': 1430
#   - 'secondary': 130
#   - 'steps': 95
#   - 'primary': 88
#   - 'tertiary': 77
#   - 'motorway_link': 67
#   - 'unclassified': 66
#   - 'motorway': 65
#   - 'trunk_link': 40
#   - 'secondary_link': 18
#   - 'trunk': 18
#   - 'path': 17
#   - 'primary_link': 12
#   - 'construction': 9
#   - 'tertiary_link': 6
#   - 'living_street': 5
#   - 'track': 4
#   - 'cycleway': 3
# {'category': category
#  parking_aisle       1547
#  sidewalk             238
#  driveway             168
#  crossing              68
#  drive-through          8
#  motorway_link          4
#  Busway                 2
#  access_aisle           2
#  alley                  2
#  emergency_access       2
#  dtype: int64,
#  'label': label
#  service           3432
#  footway           2601
#  residential       1430
#  secondary          130
#  steps               95
#  primary             88
#  tertiary            77
#  motorway_link       67
#  unclassified        66
#  motorway            65
#  trunk_link          40
#  secondary_link      18
#  trunk               18
#  path                17
#  primary_link        12
#  construction         9
#  tertiary_link        6
#  living_street        5
#  track                4
#  cycleway             3
#  dtype: int64}

# %%
import geopandas as gpd
import shapely.geometry as shp

fp = os.path.join(set_folder, 'ungrouped.shp')
gdf = gpd.read_file(fp)
gv.gdf_overview(gdf, f"Ungrouped GDF")
values = gv.gdf_value_columns(gdf, [k for k in gdf.columns if k not in ['name', 'index', 'geometry']])
# Out:
# Ungrouped GDF:
# --------------
# - Rows: 1251
# - Keys: 132
#
# tiger_cfcc (3)
#   - 'B11': 27
#   - 'A41': 9
#   - 'B11:B13': 1
#
# tiger_coun (4)
#   - 'Tuscaloosa, AL': 25
#   - 'Hale, AL:Tuscaloosa, AL': 10
#   - 'Bibb, AL:Jefferson, AL:Tuscaloosa, AL': 1
#   - 'Jefferson, AL:Tuscaloosa, AL': 1
#
# tiger_name (7)
#   - 'Illinois Central Railroad': 11
#   - 'Alabama Great Southern RR:Illinois Central Railroad:Southern Railway': 10
#   - 'Snows Mill Creek': 9
#   - 'Illinois Central Railroad:Kansas City Southern Railroad': 4
#   - 'Alabama Great Southern RR:Southern Railway': 1
#   - 'Kansas City Southern Railroad': 1
#   - 'Kansas City Southern Railroad:Louisville and Nashville RR:Seaboard System Railroad': 1
#
# tiger_revi (2)
#   - 'no': 30
#   - 'aerial': 1
#
# tiger_sepa (1)
#   - 'no': 1
#
# tiger_sour (1)
#   - 'tiger_import_dch_v0.6_20070809': 2
#
# tiger_tlid (2)
#   - '82175261:82175262:82150697:82175372:82156169:82174388:82174389:82175253:82203406:82150516:82202365:82202366:82150520:82166385:82214867:82214868:82214601:82214603:82214605:82214606:82203374:82170610:82218605:82218606:82199544:82203370:82170651:82214599:82': 1
#   - '82214133:82214134:82147735:82156124': 1
#
# tiger_uplo (1)
#   - 'bulk_upload.pl-c76bc891-ffd2-4a70-bdbb-88c998a4763c': 2
#
# surface (7)
#   - 'asphalt': 5
#   - 'sand': 4
#   - 'concrete': 3
#   - 'grass': 1
#   - 'gravel': 1
#   - 'unpaved': 1
#   - 'wood': 1
#
# service (4)
#   - 'spur': 24
#   - 'siding': 20
#   - 'yard': 20
#   - 'crossover': 2
#
# ref (2)
#   - '3AL3': 1
#   - 'AL26': 1
#
# access (6)
#   - 'customers': 28
#   - 'private': 16
#   - 'no': 2
#   - 'yes': 2
#   - 'permissive': 1
#   - 'permit': 1
#
# electrifie (1)
#   - 'no': 36
#
# gauge (1)
#   - '1435': 38
#
# old_railwa (3)
#   - 'Southern': 15
#   - 'GM&O': 13
#   - 'L&N': 3
#
# operator (15)
#   - 'Norfolk Southern Railway': 15
#   - 'Alabama Southern Railroad': 14
#   - 'BELL PARTNERS INC': 1
#   - 'City of Tuscaloosa': 1
#   - 'College Station Properties': 1
#   - 'College Town Communities': 1
#   - 'DCH Health System': 1
#   - 'Kilgore-Deas Properties, LLP': 1
#   - 'NOAA, National Weather Service': 1
#   - 'OUT OF BUSINESS': 1
#   - 'Publix': 1
#   - 'Sealy Management Co Inc.': 1
#   - 'Tuscaloosa Police Department': 1
#   - 'Tuscaloosa Public Library': 1
#   - 'Willow Ridge HOA': 1
#
# railway (4)
#   - 'rail': 93
#   - 'abandoned': 6
#   - 'disused': 2
#   - 'platform': 1
#
# usage (3)
#   - 'branch': 16
#   - 'main': 10
#   - 'industrial': 2
#
# bridge (2)
#   - 'yes': 10
#   - 'trestle': 1
#
# layer (3)
#   - '-1': 42
#   - '1': 11
#   - '-5': 1
#
# descriptio (9)
#   - 'Fence around the Rear Loading dock with Fleet vehicle parking and Bulk Bussiness mail Center drop off and deliveries [ gates are locked at 7pm daily].': 1
#   - 'Golf, Tennis, Swimming, Dining,': 1
#   - 'Little League Baseball , Softball fields, youth football and Soccer practice fields.': 1
#   - 'Playground, Baseball field': 1
#   - 'Tire swings, Prayer Bench, Basketball Goal': 1
#   - 'Tuscaloosa County Area': 1
#   - 'USPS Fleet vehicles and employee parking lot': 1
#   - 'Walking Paths, Fountain, Playground, Restrooms': 1
#   - 'this area is no longer in use as anything.
# ': 1
#
# wikidata (9)
#   - 'Q1274870': 1
#   - 'Q30688010': 1
#   - 'Q35247952': 1
#   - 'Q492318': 1
#   - 'Q4980690': 1
#   - 'Q5061206': 1
#   - 'Q61671574': 1
#   - 'Q7320821': 1
#   - 'Q995161': 1
#
# wikipedia (4)
#   - 'en:Bryant?Denny Stadium': 1
#   - 'en:Bryce Hospital': 1
#   - 'en:Holt, Alabama': 1
#   - 'en:University of Alabama': 1
#
# foot (1)
#   - 'yes': 1
#
# lit (2)
#   - 'no': 3
#   - 'yes': 1
#
# parking (1)
#   - 'surface': 33
#
# note (1)
#   - 'Destroyed by April 27, 2011 tornado.': 1
#
# source (2)
#   - 'TIGER/Line® 2008 Place Shapefiles (http://www.census.gov/geo/www/tiger/)': 5
#   - 'USGS Geonames': 1
#
# railway_tr (1)
#   - 'mixed': 10
#
# waterway (3)
#   - 'stream': 67
#   - 'drain': 48
#   - 'river': 9
#
# admin_leve (1)
#   - '8': 4
#
# border_typ (1)
#   - 'city': 4
#
# boundary (1)
#   - 'administrative': 5
#
# tiger_CLAS (2)
#   - 'C1': 4
#   - 'U1': 1
#
# tiger_CPI (2)
#   - 'Y': 4
#   - 'N': 1
#
# tiger_FUNC (2)
#   - 'A': 4
#   - 'S': 1
#
# tiger_LSAD (2)
#   - '25': 4
#   - '57': 1
#
# tiger_MTFC (2)
#   - 'G4110': 4
#   - 'G4210': 1
#
# tiger_NA_1 (2)
#   - 'Tuscaloosa': 4
#   - 'Holt': 1
#
# tiger_NA_2 (2)
#   - 'Tuscaloosa city': 4
#   - 'Holt CDP': 1
#
# tiger_PCIC (2)
#   - 'Y': 4
#   - 'N': 1
#
# tiger_PCIN (1)
#   - 'N': 5
#
# tiger_PLAC (2)
#   - '77256': 4
#   - '35704': 1
#
# tiger_PL_1 (2)
#   - '02405614': 4
#   - '02402595': 1
#
# tiger_PLCI (2)
#   - '0177256': 4
#   - '0135704': 1
#
# tiger_STAT (1)
#   - '01': 5
#
# amenity (12)
#   - 'parking': 170
#   - 'school': 14
#   - 'shelter': 8
#   - 'fuel': 4
#   - 'university': 3
#   - 'hospital': 2
#   - 'prison': 2
#   - 'bar': 1
#   - 'car_rental': 1
#   - 'fountain': 1
#   - 'grave_yard': 1
#   - 'social_facility': 1
#
# addr_city (2)
#   - 'Tuscaloosa': 17
#   - 'Northport': 3
#
# addr_postc (5)
#   - '35401': 6
#   - '35406': 4
#   - '35404': 3
#   - '35476': 3
#   - '35405': 2
#
# emergency (2)
#   - 'no': 1
#   - 'yes': 1
#
# healthcare (1)
#   - 'hospital': 2
#
# healthca_1 (1)
#   - 'psychiatry': 1
#
# landuse (11)
#   - 'forest': 92
#   - 'residential': 27
#   - 'retail': 25
#   - 'commercial': 10
#   - 'industrial': 8
#   - 'cemetery': 7
#   - 'construction': 4
#   - 'grass': 4
#   - 'reservoir': 3
#   - 'meadow': 1
#   - 'plant_nursery': 1
#
# ele (9)
#   - '43': 2
#   - '61': 2
#   - '67': 2
#   - '107': 1
#   - '119': 1
#   - '128': 1
#   - '47.4': 1
#   - '69': 1
#   - '99': 1
#
# gnis_count (1)
#   - '125': 9
#
# gnis_creat (2)
#   - '12/01/2003': 7
#   - '09/04/1980': 2
#
# gnis_featu (18)
#   - '117484': 1
#   - '118082': 1
#   - '165349': 1
#   - '165347': 1
#   - '164315': 1
#   - '158756': 1
#   - '157848': 1
#   - '148252': 1
#   - '148080': 1
#   - '148007': 1
#   - '147926': 1
#   - '131265': 1
#   - '131263': 1
#   - '127834': 1
#   - '122651': 1
#   - '119384': 1
#   - '118499': 1
#   - '1700130': 1
#
# gnis_state (1)
#   - '01': 9
#
# note_old_r (1)
#   - 'M&O': 13
#
# natural (4)
#   - 'wood': 56
#   - 'water': 54
#   - 'wetland': 3
#   - 'grassland': 1
#
# water (8)
#   - 'pond': 20
#   - 'basin': 8
#   - 'lake': 4
#   - 'reservoir': 4
#   - 'wastewater': 2
#   - 'fishpond': 1
#   - 'river': 1
#   - 'shallow': 1
#
# capacity (5)
#   - '100': 1
#   - '101821': 1
#   - '20': 1
#   - '3': 1
#   - '77': 1
#
# leisure (7)
#   - 'pitch': 99
#   - 'park': 53
#   - 'swimming_pool': 47
#   - 'playground': 37
#   - 'stadium': 4
#   - 'sports_centre': 2
#   - 'golf_course': 1
#
# sport (9)
#   - 'tennis': 43
#   - 'baseball': 24
#   - 'american_football': 7
#   - 'basketball': 5
#   - 'beachvolleyball': 5
#   - 'swimming': 5
#   - 'softball': 3
#   - 'soccer': 2
#   - 'volleyball': 1
#
# wheelchair (1)
#   - 'yes': 5
#
# area (1)
#   - 'yes': 15
#
# addr_house (18)
#   - '1125': 1
#   - '1130': 1
#   - '809': 1
#   - '680': 1
#   - '500': 1
#   - '2929': 1
#   - '2901': 1
#   - '2412': 1
#   - '201': 1
#   - '1900': 1
#   - '1800': 1
#   - '1701': 1
#   - '1700': 1
#   - '1650': 1
#   - '1603': 1
#   - '1513': 1
#   - '1229': 1
#   - '951': 1
#
# addr_stree (18)
#   - 'Jack Warner Parkway Northeast': 2
#   - '12th Street': 1
#   - 'McFarland Boulevard North': 1
#   - 'University Boulevard': 1
#   - 'Snows Mill Avenue': 1
#   - 'Skyland Boulevard East': 1
#   - 'Rose Drive': 1
#   - 'Rice Mine Road North': 1
#   - 'Pine Street': 1
#   - 'McFarland Boulevard East': 1
#   - '20th Street': 1
#   - 'McFarland Boulevard': 1
#   - 'Marina Drive': 1
#   - 'Holt Road Northeast': 1
#   - 'Greensboro Avenue': 1
#   - 'Campus Dr W': 1
#   - '6th Avenue Northeast': 1
#   - 'University Boulevard East': 1
#
# barrier (4)
#   - 'fence': 26
#   - 'hedge': 21
#   - 'wall': 4
#   - 'gate': 2
#
# fee (2)
#   - 'no': 26
#   - 'yes': 1
#
# roof_shape (3)
#   - 'skillion': 3
#   - 'gabled': 2
#   - 'hipped': 1
#
# addr_state (1)
#   - 'AL': 18
#
# power (4)
#   - 'line': 16
#   - 'substation': 7
#   - 'minor_line': 1
#   - 'transformer': 1
#
# voltage (2)
#   - '115000': 11
#   - '230000': 1
#
# website (9)
#   - 'www.tcpara.org': 2
#   - 'https://www.bellapartmentliving.com/al/tuscaloosa/high-river-0/index.aspx': 1
#   - 'https://www.brookdale.com/en/communities/brookdale-northport.html': 1
#   - 'https://www.cityofnorthport.org/': 1
#   - 'https://www.dchsystem.com/': 1
#   - 'https://www.forrent.com/al/tuscaloosa/royal-hills/zp845kx': 1
#   - 'https://www.indianhillscountryclub.net/': 1
#   - 'https://www.myrivermont.com/': 1
#   - 'www.tuscaloosaveteranspark.org': 1
#
# brand (1)
#   - 'Shell': 2
#
# brand_wiki (1)
#   - 'Q154950': 2
#
# brand_wi_1 (1)
#   - 'en:Royal Dutch Shell': 2
#
# opening_ho (2)
#   - '24/7': 1
#   - 'Tu-Su 06:00-19:00': 1
#
# phone (7)
#   - '(205) 752-0278': 1
#   - '+1 205 330 1700': 1
#   - '+1 205 349 1500': 1
#   - '+1 205 759 7111': 1
#   - '+1--877-633-2621': 1
#   - '+1-205-349-1787': 1
#   - '205-339-7000': 1
#
# tunnel (4)
#   - 'culvert': 34
#   - 'yes': 11
#   - 'no': 8
#   - 'building_passage': 1
#
# historic (2)
#   - 'ruins': 1
#   - 'yes': 1
#
# historic_c (1)
#   - 'modern': 1
#
# park_ride (1)
#   - 'no': 2
#
# gnis_cou_1 (1)
#   - 'Tuscaloosa': 1
#
# gnis_impor (1)
#   - '57871b70-0100-4405-bb30-88b2e001a944': 1
#
# gnis_revie (1)
#   - 'no': 1
#
# location (3)
#   - 'outdoor': 2
#   - 'underground': 1
#   - 'yes': 1
#
# boat (1)
#   - 'yes': 1
#
# deep_draft (1)
#   - 'no': 1
#
# ship (1)
#   - 'yes': 1
#
# source_dee (1)
#   - 'National Transportation Atlas Database 2011': 1
#
# email (1)
#   - 'webmaster@cityofnorthport.org': 1
#
# fax (1)
#   - '205-333-3046': 1
#
# shelter_ty (1)
#   - 'pavilion': 8
#
# is_in_coun (1)
#   - 'USA': 1
#
# is_in_co_1 (1)
#   - 'US': 1
#
# is_in_iso_ (1)
#   - 'US:AL': 1
#
# is_in_stat (1)
#   - 'Alabama': 1
#
# is_in_st_1 (1)
#   - 'AL': 1
#
# operator_t (1)
#   - 'government': 2
#
# supervised (2)
#   - 'no': 2
#   - 'yes': 1
#
# man_made (6)
#   - 'pier': 5
#   - 'bridge': 2
#   - 'pipeline': 1
#   - 'wastewater_plant': 1
#   - 'water_tower': 1
#   - 'water_works': 1
#
# frequency (1)
#   - '60': 1
#
# substation (1)
#   - 'transmission': 1
#
# width (2)
#   - '2.8': 2
#   - '2.5': 1
#
# aeroway (1)
#   - 'helipad': 2
#
# faa (2)
#   - '3AL3': 1
#   - 'AL26': 1
#
# beds (1)
#   - '583': 1
#
# start_date (2)
#   - '2020': 1
#   - 'August 31, 2004': 1
#
# leaf_type (1)
#   - 'mixed': 85
#
# network (1)
#   - 'Amtrak': 1
#
# public_tra (1)
#   - 'platform': 1
#
# train (1)
#   - 'yes': 1
#
# intermitte (1)
#   - 'no': 1
#
# social_fac (1)
#   - 'assisted_living': 1
#
# fence_type (4)
#   - 'chain_link': 9
#   - 'metal': 5
#   - 'wood': 5
#   - 'brick': 3
#
# residentia (1)
#   - 'apartments': 5
#
# material (1)
#   - 'metal': 2
#
# constructi (2)
#   - 'residential': 3
#   - 'building': 1
#
# building_m (3)
#   - 'brick': 7
#   - 'other': 2
#   - 'wood': 1
#
# building_p (1)
#   - 'yes': 12
#
# height (10)
#   - '3.42': 3
#   - '0.91': 2
#   - '3': 2
#   - '4': 2
#   - '7.01': 2
#   - '1.83': 1
#   - '10.97': 1
#   - '12.08': 1
#   - '6.71': 1
#   - '9.9': 1
#
# roof_colou (3)
#   - 'white': 5
#   - 'brown': 3
#   - 'grey': 1
#
# roof_heigh (5)
#   - '0.81': 2
#   - '0.91': 1
#   - '2.9': 1
#   - '3.05': 1
#   - '3.96': 1
#
# roof_orien (1)
#   - 'along': 2
#
# min_height (3)
#   - '0.91': 2
#   - '2.51': 1
#   - '7.01': 1
#
# roof_direc (2)
#   - '111.0': 2
#   - '291.0': 1
#
# bridge_str (1)
#   - 'arch': 1
# {'tiger_cfcc': tiger_cfcc
#  B11        27
#  A41         9
#  B11:B13     1
#  dtype: int64,
#  'tiger_coun': tiger_coun
#  Tuscaloosa, AL                           25
#  Hale, AL:Tuscaloosa, AL                  10
#  Bibb, AL:Jefferson, AL:Tuscaloosa, AL     1
#  Jefferson, AL:Tuscaloosa, AL              1
#  dtype: int64,
#  'tiger_name': tiger_name
#  Illinois Central Railroad                                                             11
#  Alabama Great Southern RR:Illinois Central Railroad:Southern Railway                  10
#  Snows Mill Creek                                                                       9
#  Illinois Central Railroad:Kansas City Southern Railroad                                4
#  Alabama Great Southern RR:Southern Railway                                             1
#  Kansas City Southern Railroad                                                          1
#  Kansas City Southern Railroad:Louisville and Nashville RR:Seaboard System Railroad     1
#  dtype: int64,
#  'tiger_revi': tiger_revi
#  no        30
#  aerial     1
#  dtype: int64,
#  'tiger_sepa': tiger_sepa
#  no    1
#  dtype: int64,
#  'tiger_sour': tiger_sour
#  tiger_import_dch_v0.6_20070809    2
#  dtype: int64,
#  'tiger_tlid': tiger_tlid
#  82175261:82175262:82150697:82175372:82156169:82174388:82174389:82175253:82203406:82150516:82202365:82202366:82150520:82166385:82214867:82214868:82214601:82214603:82214605:82214606:82203374:82170610:82218605:82218606:82199544:82203370:82170651:82214599:82    1
#  82214133:82214134:82147735:82156124                                                                                                                                                                                                                               1
#  dtype: int64,
#  'tiger_uplo': tiger_uplo
#  bulk_upload.pl-c76bc891-ffd2-4a70-bdbb-88c998a4763c    2
#  dtype: int64,
#  'surface': surface
#  asphalt     5
#  sand        4
#  concrete    3
#  grass       1
#  gravel      1
#  unpaved     1
#  wood        1
#  dtype: int64,
#  'service': service
#  spur         24
#  siding       20
#  yard         20
#  crossover     2
#  dtype: int64,
#  'ref': ref
#  3AL3    1
#  AL26    1
#  dtype: int64,
#  'access': access
#  customers     28
#  private       16
#  no             2
#  yes            2
#  permissive     1
#  permit         1
#  dtype: int64,
#  'electrifie': electrifie
#  no    36
#  dtype: int64,
#  'gauge': gauge
#  1435    38
#  dtype: int64,
#  'old_railwa': old_railwa
#  Southern    15
#  GM&O        13
#  L&N          3
#  dtype: int64,
#  'operator': operator
#  Norfolk Southern Railway          15
#  Alabama Southern Railroad         14
#  BELL PARTNERS INC                  1
#  City of Tuscaloosa                 1
#  College Station Properties         1
#  College Town Communities           1
#  DCH Health System                  1
#  Kilgore-Deas Properties, LLP       1
#  NOAA, National Weather Service     1
#  OUT OF BUSINESS                    1
#  Publix                             1
#  Sealy Management Co Inc.           1
#  Tuscaloosa Police Department       1
#  Tuscaloosa Public Library          1
#  Willow Ridge HOA                   1
#  dtype: int64,
#  'railway': railway
#  rail         93
#  abandoned     6
#  disused       2
#  platform      1
#  dtype: int64,
#  'usage': usage
#  branch        16
#  main          10
#  industrial     2
#  dtype: int64,
#  'bridge': bridge
#  yes        10
#  trestle     1
#  dtype: int64,
#  'layer': layer
#  -1    42
#  1     11
#  -5     1
#  dtype: int64,
#  'descriptio': descriptio
#  Fence around the Rear Loading dock with Fleet vehicle parking and Bulk Bussiness mail Center drop off and deliveries [ gates are locked at 7pm daily].    1
#  Golf, Tennis, Swimming, Dining,                                                                                                                           1
#  Little League Baseball , Softball fields, youth football and Soccer practice fields.                                                                      1
#  Playground, Baseball field                                                                                                                                1
#  Tire swings, Prayer Bench, Basketball Goal                                                                                                                1
#  Tuscaloosa County Area                                                                                                                                    1
#  USPS Fleet vehicles and employee parking lot                                                                                                              1
#  Walking Paths, Fountain, Playground, Restrooms                                                                                                            1
#  this area is no longer in use as anything.\n                                                                                                              1
#  dtype: int64,
#  'wikidata': wikidata
#  Q1274870     1
#  Q30688010    1
#  Q35247952    1
#  Q492318      1
#  Q4980690     1
#  Q5061206     1
#  Q61671574    1
#  Q7320821     1
#  Q995161      1
#  dtype: int64,
#  'wikipedia': wikipedia
#  en:Bryant?Denny Stadium     1
#  en:Bryce Hospital           1
#  en:Holt, Alabama            1
#  en:University of Alabama    1
#  dtype: int64,
#  'foot': foot
#  yes    1
#  dtype: int64,
#  'lit': lit
#  no     3
#  yes    1
#  dtype: int64,
#  'parking': parking
#  surface    33
#  dtype: int64,
#  'note': note
#  Destroyed by April 27, 2011 tornado.    1
#  dtype: int64,
#  'source': source
#  TIGER/Line® 2008 Place Shapefiles (http://www.census.gov/geo/www/tiger/)    5
#  USGS Geonames                                                               1
#  dtype: int64,
#  'railway_tr': railway_tr
#  mixed    10
#  dtype: int64,
#  'waterway': waterway
#  stream    67
#  drain     48
#  river      9
#  dtype: int64,
#  'admin_leve': admin_leve
#  8    4
#  dtype: int64,
#  'border_typ': border_typ
#  city    4
#  dtype: int64,
#  'boundary': boundary
#  administrative    5
#  dtype: int64,
#  'tiger_CLAS': tiger_CLAS
#  C1    4
#  U1    1
#  dtype: int64,
#  'tiger_CPI': tiger_CPI
#  Y    4
#  N    1
#  dtype: int64,
#  'tiger_FUNC': tiger_FUNC
#  A    4
#  S    1
#  dtype: int64,
#  'tiger_LSAD': tiger_LSAD
#  25    4
#  57    1
#  dtype: int64,
#  'tiger_MTFC': tiger_MTFC
#  G4110    4
#  G4210    1
#  dtype: int64,
#  'tiger_NA_1': tiger_NA_1
#  Tuscaloosa    4
#  Holt          1
#  dtype: int64,
#  'tiger_NA_2': tiger_NA_2
#  Tuscaloosa city    4
#  Holt CDP           1
#  dtype: int64,
#  'tiger_PCIC': tiger_PCIC
#  Y    4
#  N    1
#  dtype: int64,
#  'tiger_PCIN': tiger_PCIN
#  N    5
#  dtype: int64,
#  'tiger_PLAC': tiger_PLAC
#  77256    4
#  35704    1
#  dtype: int64,
#  'tiger_PL_1': tiger_PL_1
#  02405614    4
#  02402595    1
#  dtype: int64,
#  'tiger_PLCI': tiger_PLCI
#  0177256    4
#  0135704    1
#  dtype: int64,
#  'tiger_STAT': tiger_STAT
#  01    5
#  dtype: int64,
#  'amenity': amenity
#  parking            170
#  school              14
#  shelter              8
#  fuel                 4
#  university           3
#  hospital             2
#  prison               2
#  bar                  1
#  car_rental           1
#  fountain             1
#  grave_yard           1
#  social_facility      1
#  dtype: int64,
#  'addr_city': addr_city
#  Tuscaloosa    17
#  Northport      3
#  dtype: int64,
#  'addr_postc': addr_postc
#  35401    6
#  35406    4
#  35404    3
#  35476    3
#  35405    2
#  dtype: int64,
#  'emergency': emergency
#  no     1
#  yes    1
#  dtype: int64,
#  'healthcare': healthcare
#  hospital    2
#  dtype: int64,
#  'healthca_1': healthca_1
#  psychiatry    1
#  dtype: int64,
#  'landuse': landuse
#  forest           92
#  residential      27
#  retail           25
#  commercial       10
#  industrial        8
#  cemetery          7
#  construction      4
#  grass             4
#  reservoir         3
#  meadow            1
#  plant_nursery     1
#  dtype: int64,
#  'ele': ele
#  43      2
#  61      2
#  67      2
#  107     1
#  119     1
#  128     1
#  47.4    1
#  69      1
#  99      1
#  dtype: int64,
#  'gnis_count': gnis_count
#  125    9
#  dtype: int64,
#  'gnis_creat': gnis_creat
#  12/01/2003    7
#  09/04/1980    2
#  dtype: int64,
#  'gnis_featu': gnis_featu
#  117484     1
#  118082     1
#  165349     1
#  165347     1
#  164315     1
#  158756     1
#  157848     1
#  148252     1
#  148080     1
#  148007     1
#  147926     1
#  131265     1
#  131263     1
#  127834     1
#  122651     1
#  119384     1
#  118499     1
#  1700130    1
#  dtype: int64,
#  'gnis_state': gnis_state
#  01    9
#  dtype: int64,
#  'note_old_r': note_old_r
#  M&O    13
#  dtype: int64,
#  'natural': natural
#  wood         56
#  water        54
#  wetland       3
#  grassland     1
#  dtype: int64,
#  'water': water
#  pond          20
#  basin          8
#  lake           4
#  reservoir      4
#  wastewater     2
#  fishpond       1
#  river          1
#  shallow        1
#  dtype: int64,
#  'capacity': capacity
#  100       1
#  101821    1
#  20        1
#  3         1
#  77        1
#  dtype: int64,
#  'leisure': leisure
#  pitch            99
#  park             53
#  swimming_pool    47
#  playground       37
#  stadium           4
#  sports_centre     2
#  golf_course       1
#  dtype: int64,
#  'sport': sport
#  tennis               43
#  baseball             24
#  american_football     7
#  basketball            5
#  beachvolleyball       5
#  swimming              5
#  softball              3
#  soccer                2
#  volleyball            1
#  dtype: int64,
#  'wheelchair': wheelchair
#  yes    5
#  dtype: int64,
#  'area': area
#  yes    15
#  dtype: int64,
#  'addr_house': addr_house
#  1125    1
#  1130    1
#  809     1
#  680     1
#  500     1
#  2929    1
#  2901    1
#  2412    1
#  201     1
#  1900    1
#  1800    1
#  1701    1
#  1700    1
#  1650    1
#  1603    1
#  1513    1
#  1229    1
#  951     1
#  dtype: int64,
#  'addr_stree': addr_stree
#  Jack Warner Parkway Northeast    2
#  12th Street                      1
#  McFarland Boulevard North        1
#  University Boulevard             1
#  Snows Mill Avenue                1
#  Skyland Boulevard East           1
#  Rose Drive                       1
#  Rice Mine Road North             1
#  Pine Street                      1
#  McFarland Boulevard East         1
#  20th Street                      1
#  McFarland Boulevard              1
#  Marina Drive                     1
#  Holt Road Northeast              1
#  Greensboro Avenue                1
#  Campus Dr W                      1
#  6th Avenue Northeast             1
#  University Boulevard East        1
#  dtype: int64,
#  'barrier': barrier
#  fence    26
#  hedge    21
#  wall      4
#  gate      2
#  dtype: int64,
#  'fee': fee
#  no     26
#  yes     1
#  dtype: int64,
#  'roof_shape': roof_shape
#  skillion    3
#  gabled      2
#  hipped      1
#  dtype: int64,
#  'addr_state': addr_state
#  AL    18
#  dtype: int64,
#  'power': power
#  line           16
#  substation      7
#  minor_line      1
#  transformer     1
#  dtype: int64,
#  'voltage': voltage
#  115000    11
#  230000     1
#  dtype: int64,
#  'website': website
#  www.tcpara.org                                                               2
#  https://www.bellapartmentliving.com/al/tuscaloosa/high-river-0/index.aspx    1
#  https://www.brookdale.com/en/communities/brookdale-northport.html            1
#  https://www.cityofnorthport.org/                                             1
#  https://www.dchsystem.com/                                                   1
#  https://www.forrent.com/al/tuscaloosa/royal-hills/zp845kx                    1
#  https://www.indianhillscountryclub.net/                                      1
#  https://www.myrivermont.com/                                                 1
#  www.tuscaloosaveteranspark.org                                               1
#  dtype: int64,
#  'brand': brand
#  Shell    2
#  dtype: int64,
#  'brand_wiki': brand_wiki
#  Q154950    2
#  dtype: int64,
#  'brand_wi_1': brand_wi_1
#  en:Royal Dutch Shell    2
#  dtype: int64,
#  'opening_ho': opening_ho
#  24/7                 1
#  Tu-Su 06:00-19:00    1
#  dtype: int64,
#  'phone': phone
#  (205) 752-0278      1
#  +1 205 330 1700     1
#  +1 205 349 1500     1
#  +1 205 759 7111     1
#  +1--877-633-2621    1
#  +1-205-349-1787     1
#  205-339-7000        1
#  dtype: int64,
#  'tunnel': tunnel
#  culvert             34
#  yes                 11
#  no                   8
#  building_passage     1
#  dtype: int64,
#  'historic': historic
#  ruins    1
#  yes      1
#  dtype: int64,
#  'historic_c': historic_c
#  modern    1
#  dtype: int64,
#  'park_ride': park_ride
#  no    2
#  dtype: int64,
#  'gnis_cou_1': gnis_cou_1
#  Tuscaloosa    1
#  dtype: int64,
#  'gnis_impor': gnis_impor
#  57871b70-0100-4405-bb30-88b2e001a944    1
#  dtype: int64,
#  'gnis_revie': gnis_revie
#  no    1
#  dtype: int64,
#  'location': location
#  outdoor        2
#  underground    1
#  yes            1
#  dtype: int64,
#  'boat': boat
#  yes    1
#  dtype: int64,
#  'deep_draft': deep_draft
#  no    1
#  dtype: int64,
#  'ship': ship
#  yes    1
#  dtype: int64,
#  'source_dee': source_dee
#  National Transportation Atlas Database 2011    1
#  dtype: int64,
#  'email': email
#  webmaster@cityofnorthport.org    1
#  dtype: int64,
#  'fax': fax
#  205-333-3046    1
#  dtype: int64,
#  'shelter_ty': shelter_ty
#  pavilion    8
#  dtype: int64,
#  'is_in_coun': is_in_coun
#  USA    1
#  dtype: int64,
#  'is_in_co_1': is_in_co_1
#  US    1
#  dtype: int64,
#  'is_in_iso_': is_in_iso_
#  US:AL    1
#  dtype: int64,
#  'is_in_stat': is_in_stat
#  Alabama    1
#  dtype: int64,
#  'is_in_st_1': is_in_st_1
#  AL    1
#  dtype: int64,
#  'operator_t': operator_t
#  government    2
#  dtype: int64,
#  'supervised': supervised
#  no     2
#  yes    1
#  dtype: int64,
#  'man_made': man_made
#  pier                5
#  bridge              2
#  pipeline            1
#  wastewater_plant    1
#  water_tower         1
#  water_works         1
#  dtype: int64,
#  'frequency': frequency
#  60    1
#  dtype: int64,
#  'substation': substation
#  transmission    1
#  dtype: int64,
#  'width': width
#  2.8    2
#  2.5    1
#  dtype: int64,
#  'aeroway': aeroway
#  helipad    2
#  dtype: int64,
#  'faa': faa
#  3AL3    1
#  AL26    1
#  dtype: int64,
#  'beds': beds
#  583    1
#  dtype: int64,
#  'start_date': start_date
#  2020               1
#  August 31, 2004    1
#  dtype: int64,
#  'leaf_type': leaf_type
#  mixed    85
#  dtype: int64,
#  'network': network
#  Amtrak    1
#  dtype: int64,
#  'public_tra': public_tra
#  platform    1
#  dtype: int64,
#  'train': train
#  yes    1
#  dtype: int64,
#  'intermitte': intermitte
#  no    1
#  dtype: int64,
#  'social_fac': social_fac
#  assisted_living    1
#  dtype: int64,
#  'fence_type': fence_type
#  chain_link    9
#  metal         5
#  wood          5
#  brick         3
#  dtype: int64,
#  'residentia': residentia
#  apartments    5
#  dtype: int64,
#  'material': material
#  metal    2
#  dtype: int64,
#  'constructi': constructi
#  residential    3
#  building       1
#  dtype: int64,
#  'building_m': building_m
#  brick    7
#  other    2
#  wood     1
#  dtype: int64,
#  'building_p': building_p
#  yes    12
#  dtype: int64,
#  'height': height
#  3.42     3
#  0.91     2
#  3        2
#  4        2
#  7.01     2
#  1.83     1
#  10.97    1
#  12.08    1
#  6.71     1
#  9.9      1
#  dtype: int64,
#  'roof_colou': roof_colou
#  white    5
#  brown    3
#  grey     1
#  dtype: int64,
#  'roof_heigh': roof_heigh
#  0.81    2
#  0.91    1
#  2.9     1
#  3.05    1
#  3.96    1
#  dtype: int64,
#  'roof_orien': roof_orien
#  along    2
#  dtype: int64,
#  'min_height': min_height
#  0.91    2
#  2.51    1
#  7.01    1
#  dtype: int64,
#  'roof_direc': roof_direc
#  111.0    2
#  291.0    1
#  dtype: int64,
#  'bridge_str': bridge_str
#  arch    1
#  dtype: int64}
